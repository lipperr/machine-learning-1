# %% [markdown]
# # Машинное обучение, ФКН ВШЭ
#
# # Практическое задание 6. Бустинговое
#
# ## Общая информация
#
# Дата выдачи: 12.12.2023
#
# Мягкий дедлайн: 24.12.2023 23:59 MSK
#
# Жёсткий дедлайн: 24.12.2023 23:59 MSK
#
# ## Оценивание и штрафы
#
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.
#
# ## Формат сдачи
# Задания сдаются через систему anytask. Посылка должна содержать:
# * Ноутбук homework-practice-06-Username.ipynb
#
# Username — ваша фамилия на латинице

# %% [markdown]
# ## О задании
#
# В этом задании вам предстоит вручную запрограммировать один из самых мощных алгоритмов машинного обучения — бустинг.

# %%
from warnings import filterwarnings

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.sparse import load_npz
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

sns.set(style='darkgrid')
filterwarnings('ignore')

# %%
x = load_npz('x.npz')
y = np.load('y.npy')

# %% [markdown]
# Разделим на обучающую, валидационную и тестовую выборки (`random_state` оставьте равным 1337 для воспроизводимости).

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1337)

x_test, x_valid, y_test, y_valid = train_test_split(x_test, y_test, test_size=0.5, random_state=1337)

x_train.shape, x_valid.shape, x_test.shape
# Out:
# ((18825, 169), (2354, 169), (2353, 169))

# %% [markdown]
# ## Задание 1. Реализация градиентного бустингового (4 балла)
#
# Вам нужно дописать код в файлике `boosting.py`. Для вас уже подготовлен шаблон класса `Boosting`, вы можете менять его по своему усмотрению.
#
# ### Инструкции для функций:
#
# #### `__init__`
#
# В `__init__` приходит кучка параметров, распишем что есть что:
#
#  - `base_model_class` - класс базовой модели нашего бустинга
#  - `base_model_params` - словарь с гиперпараметрами для базовой модели
#  - `n_estimators` - какое количество базовых моделей нужно обучить
#  - `learning_rate` - темп обучения, должен быть из полуинтервала $(0, 1]$
#  - `subsample` - доля объектов, на которой будет обучаться базовая модель (какую часть составляет бутстрапная выборка от исходной обучающей)
#  - `early_stopping_rounds` - число итераций, после которых при отсутствии улучшения качества на валидационной выборке обучение останавливается
#  - `plot` - строить ли после обучения всех базовых моделей график с качеством
#
# #### `fit`
#
# В `fit` приходит две выборки, обучающая и валидационная. На обучающей мы обучаем новые базовые модели, на валидационной считаем качество для ранней остановки (если это предусматривают параметры).
#
# Сначала нам нужно сделать какую-то нулевую модель, сделать предсказания для обучающей и валидационной выборок (в шаблоне это нулевая модель, соответственно предсказания это просто `np.zeros`). После этого нужно обучить `n_estimators` базовых моделей (как и на что обучаются базовые модели смотрите в лекциях и семинарах). После каждой обученной базовой модели мы должны обновить текущие предсказания, посчитать ошибку на обучающей и валидационной выборках (используем `loss_fn` для этого), проверить на раннюю остановку.
#
# После всего цикла обучения надо нарисовать график (если `plot`).
#
#
# #### `fit_new_base_model`
#
# В `fit_new_base_model` приходит обучающая выборка (целиком) и текущие предсказания для неё. Мы должны сгенерировать бутстрап выборку для обучения базовой модели и обучить базовую модель. После обучения модели запускаем поиск оптимальной гаммы, добавляем новую модель и гамму (не забываем про темп обучения) в соответствующие списки.
#
# #### `predict_proba`
#
# В `predict_proba` приходит выборка, нужно предсказать вероятности для неё. Суммируем предсказания базовых моделей на этой выборке (не забываем про гаммы) и накидываем сигмоиду.

# %%
# %load_ext autoreload

# %%
# %autoreload 2

from boosting import Boosting

# %% [markdown]
# ### Проверка кода
#
# У автора задания всё учится около одной секунды.

# %%
boosting = Boosting(plot=True)

# %time boosting.fit(x_train, y_train, x_valid, y_valid)

assert len(boosting.models) == boosting.n_estimators
assert len(boosting.gammas) == boosting.n_estimators

assert boosting.predict_proba(x_test).shape == (x_test.shape[0], 2)

print(f'Train ROC-AUC {boosting.score(x_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(x_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(x_test, y_test):.4f}')
# Out:
# CPU times: user 1.5 s, sys: 25.4 ms, total: 1.53 s
# Wall time: 1.49 s
# Train ROC-AUC 0.0107
# Valid ROC-AUC 0.0770
# Test ROC-AUC 0.0763

# %% [markdown]
# ## Задание 2. Обучение градиентного бустингового (1 балл)
#
# Оцените качество на тестовой выборке вашей имплементации бустинга для различной максимальной глубины решающего дерева в качестве базовой модели. Здесь и далее мы будем использовать метрику ROC-AUC.
#
# Перебирайте максимальную глубину от 1 до 30 с шагом 2 (остальные параметры бустинга стоит оставить равными по умолчанию). Постройте график зависимости качества на обучающей и тестовой выборке в зависимости от глубины.

# %%
results = {'train':[], 'test':[]}

depths = range(1, 30, 2)

for max_depth in depths:
    boosting = Boosting(base_model_params={'max_depth':max_depth})
    boosting.fit(x_train, y_train, x_valid, y_valid)
    results['train'].append(boosting.score(x_train, y_train))
    results['test'].append(boosting.score(x_test, y_test))
    
    
line1, = plt.plot(depths, results['train'], label='train')
line2, = plt.plot(depths, results['test'], label='test')
plt.legend(handles=[line1, line2])
plt.xlabel('max_depth')
plt.title('ROC_AUC')
plt.show()

# %% [markdown]
# **Какая из моделей имеет лучшее качество? Как вы можете это объяснить?**
#
# `### ваше решение тут ###`

# %% [markdown]
# ## Задание 3. Подбираем гиперпараметры и ищем лучшую модель (3 балла)
#
# Подберите по валидационной выборке основные гиперпараметры для вашей модели бустинга. Следует подобрать все основные параметры для самого градиентного бустинга и для самих базовых моделей. Существуют библиотеки для подбора гиперпараметров, попробуйте использовать какую-нибудь из следующих двух - [Hyperopt](https://github.com/hyperopt/hyperopt), [Optuna](https://optuna.org/).

# %% [markdown]
# base model:
#     **max_depth**,
#     **min_samples_split**,
#     **min_samples_leaf**
#
# boosting:
#     **n_estimators**,
#     **learning_rate**,
#     **subsample**,
#     **early_stopping_rounds**

# %%
import sklearn

# %%
import optuna

def objective(trial):
    
    n_estimators = trial.suggest_int('n_estimators', 2, 20)
    learning_rate = trial.suggest_float('learning_rate', 0, 1)
    
    max_depth = np.int(trial.suggest_float('max_depth', 1, 32, log=True))
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 2, 20)
    
    model = Boosting(base_model_params={'max_depth':max_depth,\
                                        'min_samples_split':min_samples_split,\
                                        'min_samples_leaf':min_samples_leaf}, \
                     n_estimators=n_estimators, learning_rate=learning_rate)
    
    scores = []
    for _ in range(3):
        model.fit(x_train, y_train, x_valid, y_valid)
        scores.append(model.score(x_valid, y_valid))
        
    return np.mean(scores)

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

trial = study.best_trial

print('ROC-AUC: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))
# Out:
# [I 2023-12-13 02:17:35,550] A new study created in memory with name: no-name-3e758811-79a4-4194-bc93-1d339df37eb4
# [I 2023-12-13 02:17:38,060] Trial 0 finished with value: 0.06425956212839222 and parameters: {'n_estimators': 12, 'learning_rate': 0.1752358984764858, 'max_depth': 10.885670047730578, 'min_samples_split': 7, 'min_samples_leaf': 12}. Best is trial 0 with value: 0.06425956212839222.
# [I 2023-12-13 02:17:39,727] Trial 1 finished with value: 0.1630708163019333 and parameters: {'n_estimators': 14, 'learning_rate': 0.10084730819143972, 'max_depth': 1.4066761387412503, 'min_samples_split': 10, 'min_samples_leaf': 15}. Best is trial 1 with value: 0.1630708163019333.
# [I 2023-12-13 02:17:41,630] Trial 2 finished with value: 0.15508265400629348 and parameters: {'n_estimators': 16, 'learning_rate': 0.02634434395802976, 'max_depth': 1.6886199333989744, 'min_samples_split': 13, 'min_samples_leaf': 7}. Best is trial 1 with value: 0.1630708163019333.
# [I 2023-12-13 02:17:43,003] Trial 3 finished with value: 0.1034162840006077 and parameters: {'n_estimators': 11, 'learning_rate': 0.8532994213977595, 'max_depth': 2.830711960336855, 'min_samples_split': 16, 'min_samples_leaf': 7}. Best is trial 1 with value: 0.1630708163019333.
# [I 2023-12-13 02:17:46,745] Trial 4 finished with value: 0.062463898487135426 and parameters: {'n_estimators': 14, 'learning_rate': 0.1225549194240596, 'max_depth': 17.143221474163443, 'min_samples_split': 5, 'min_samples_leaf': 8}. Best is trial 1 with value: 0.1630708163019333.
# [I 2023-12-13 02:17:50,446] Trial 5 finished with value: 0.062348160795040776 and parameters: {'n_estimators': 18, 'learning_rate': 0.030041064545836105, 'max_depth': 10.95253345292202, 'min_samples_split': 14, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.1630708163019333.
# [I 2023-12-13 02:17:52,062] Trial 6 finished with value: 0.06227672270233409 and parameters: {'n_estimators': 7, 'learning_rate': 0.40310291741395265, 'max_depth': 14.83685798179548, 'min_samples_split': 15, 'min_samples_leaf': 17}. Best is trial 1 with value: 0.1630708163019333.
# [I 2023-12-13 02:17:52,637] Trial 7 finished with value: 0.0833343310720583 and parameters: {'n_estimators': 2, 'learning_rate': 0.1812591875187325, 'max_depth': 30.55982672887828, 'min_samples_split': 4, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.1630708163019333.
# [I 2023-12-13 02:17:55,067] Trial 8 finished with value: 0.06752748903219079 and parameters: {'n_estimators': 9, 'learning_rate': 0.031014596918155113, 'max_depth': 16.405742038287933, 'min_samples_split': 12, 'min_samples_leaf': 6}. Best is trial 1 with value: 0.1630708163019333.
# [I 2023-12-13 02:17:58,035] Trial 9 finished with value: 0.06493549685659088 and parameters: {'n_estimators': 16, 'learning_rate': 0.2861755870395749, 'max_depth': 8.759219756745704, 'min_samples_split': 18, 'min_samples_leaf': 13}. Best is trial 1 with value: 0.1630708163019333.
# [I 2023-12-13 02:18:00,454] Trial 10 finished with value: 0.16162795307382016 and parameters: {'n_estimators': 20, 'learning_rate': 0.6753442035589476, 'max_depth': 1.0963581867105319, 'min_samples_split': 9, 'min_samples_leaf': 20}. Best is trial 1 with value: 0.1630708163019333.
# [I 2023-12-13 02:18:02,861] Trial 11 finished with value: 0.16066759629309466 and parameters: {'n_estimators': 20, 'learning_rate': 0.6725885821617892, 'max_depth': 1.300696988090256, 'min_samples_split': 9, 'min_samples_leaf': 20}. Best is trial 1 with value: 0.1630708163019333.
# [I 2023-12-13 02:18:05,516] Trial 12 finished with value: 0.08113957194082 and parameters: {'n_estimators': 20, 'learning_rate': 0.6098745496831752, 'max_depth': 3.1025101240856765, 'min_samples_split': 9, 'min_samples_leaf': 17}. Best is trial 1 with value: 0.1630708163019333.
# [I 2023-12-13 02:18:06,265] Trial 13 finished with value: 0.16449784874227716 and parameters: {'n_estimators': 6, 'learning_rate': 0.916584538493734, 'max_depth': 1.0361545662971272, 'min_samples_split': 2, 'min_samples_leaf': 20}. Best is trial 13 with value: 0.16449784874227716.
# [I 2023-12-13 02:18:06,927] Trial 14 finished with value: 0.10676283271593262 and parameters: {'n_estimators': 5, 'learning_rate': 0.9596216776075039, 'max_depth': 2.3430374764137127, 'min_samples_split': 2, 'min_samples_leaf': 15}. Best is trial 13 with value: 0.16449784874227716.
# [I 2023-12-13 02:18:07,522] Trial 15 finished with value: 0.07709833100926727 and parameters: {'n_estimators': 4, 'learning_rate': 0.4455787140496355, 'max_depth': 4.95760352808905, 'min_samples_split': 2, 'min_samples_leaf': 17}. Best is trial 13 with value: 0.16449784874227716.
# [I 2023-12-13 02:18:08,626] Trial 16 finished with value: 0.16576045384074864 and parameters: {'n_estimators': 9, 'learning_rate': 0.7965224792951007, 'max_depth': 1.7252422684119015, 'min_samples_split': 20, 'min_samples_leaf': 10}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:09,767] Trial 17 finished with value: 0.07536146743686775 and parameters: {'n_estimators': 8, 'learning_rate': 0.8586039199500886, 'max_depth': 4.4292064151984984, 'min_samples_split': 20, 'min_samples_leaf': 10}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:10,507] Trial 18 finished with value: 0.15853030691241368 and parameters: {'n_estimators': 6, 'learning_rate': 0.9714639368125739, 'max_depth': 1.8907503747393797, 'min_samples_split': 20, 'min_samples_leaf': 2}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:11,601] Trial 19 finished with value: 0.15503808834324553 and parameters: {'n_estimators': 9, 'learning_rate': 0.7861005629621844, 'max_depth': 1.00629639118387, 'min_samples_split': 17, 'min_samples_leaf': 10}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:11,894] Trial 20 finished with value: 0.08905948890767297 and parameters: {'n_estimators': 2, 'learning_rate': 0.522409149002484, 'max_depth': 3.4465984021013596, 'min_samples_split': 6, 'min_samples_leaf': 9}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:13,483] Trial 21 finished with value: 0.1613247735332642 and parameters: {'n_estimators': 13, 'learning_rate': 0.7824901689020964, 'max_depth': 1.5850901199440937, 'min_samples_split': 11, 'min_samples_leaf': 14}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:14,765] Trial 22 finished with value: 0.10211190690751813 and parameters: {'n_estimators': 10, 'learning_rate': 0.8981324425944536, 'max_depth': 2.111182856365463, 'min_samples_split': 11, 'min_samples_leaf': 15}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:16,456] Trial 23 finished with value: 0.1550149408048266 and parameters: {'n_estimators': 14, 'learning_rate': 0.32356148527447315, 'max_depth': 1.4196515030017516, 'min_samples_split': 4, 'min_samples_leaf': 18}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:16,964] Trial 24 finished with value: 0.1648703378662599 and parameters: {'n_estimators': 4, 'learning_rate': 0.7504452142698106, 'max_depth': 1.0196048690888742, 'min_samples_split': 7, 'min_samples_leaf': 12}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:17,472] Trial 25 finished with value: 0.16332464103356156 and parameters: {'n_estimators': 4, 'learning_rate': 0.7622856051386571, 'max_depth': 1.026714709604404, 'min_samples_split': 7, 'min_samples_leaf': 11}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:18,375] Trial 26 finished with value: 0.10463964470923103 and parameters: {'n_estimators': 7, 'learning_rate': 0.5795254236158697, 'max_depth': 2.333738987022721, 'min_samples_split': 3, 'min_samples_leaf': 12}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:19,046] Trial 27 finished with value: 0.06961116658538422 and parameters: {'n_estimators': 4, 'learning_rate': 0.9985618918870363, 'max_depth': 6.21205165080232, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:19,793] Trial 28 finished with value: 0.1627514068781181 and parameters: {'n_estimators': 6, 'learning_rate': 0.6984942684917467, 'max_depth': 1.2270837849711331, 'min_samples_split': 6, 'min_samples_leaf': 9}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:21,130] Trial 29 finished with value: 0.16476125176566497 and parameters: {'n_estimators': 11, 'learning_rate': 0.887554867059287, 'max_depth': 1.8003469329288007, 'min_samples_split': 18, 'min_samples_leaf': 13}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:22,737] Trial 30 finished with value: 0.07977080744201342 and parameters: {'n_estimators': 12, 'learning_rate': 0.8306610561188508, 'max_depth': 3.7084853912238134, 'min_samples_split': 18, 'min_samples_leaf': 12}. Best is trial 16 with value: 0.16576045384074864.
# [I 2023-12-13 02:18:23,957] Trial 31 finished with value: 0.1659709101957989 and parameters: {'n_estimators': 10, 'learning_rate': 0.9226555057506453, 'max_depth': 1.7640840488917102, 'min_samples_split': 19, 'min_samples_leaf': 13}. Best is trial 31 with value: 0.1659709101957989.
# [I 2023-12-13 02:18:25,293] Trial 32 finished with value: 0.1577412951287203 and parameters: {'n_estimators': 11, 'learning_rate': 0.7320598165370704, 'max_depth': 1.7720258779044897, 'min_samples_split': 19, 'min_samples_leaf': 13}. Best is trial 31 with value: 0.1659709101957989.
# [I 2023-12-13 02:18:26,569] Trial 33 finished with value: 0.09935774893115577 and parameters: {'n_estimators': 10, 'learning_rate': 0.9090263091348173, 'max_depth': 2.6342032514447116, 'min_samples_split': 18, 'min_samples_leaf': 11}. Best is trial 31 with value: 0.1659709101957989.
# [I 2023-12-13 02:18:28,025] Trial 34 finished with value: 0.15641017863780193 and parameters: {'n_estimators': 12, 'learning_rate': 0.8207331113354973, 'max_depth': 1.5670464735648826, 'min_samples_split': 15, 'min_samples_leaf': 14}. Best is trial 31 with value: 0.1659709101957989.
# [I 2023-12-13 02:18:29,968] Trial 35 finished with value: 0.16336800941013954 and parameters: {'n_estimators': 16, 'learning_rate': 0.8789655029381247, 'max_depth': 1.9356708549035981, 'min_samples_split': 20, 'min_samples_leaf': 13}. Best is trial 31 with value: 0.1659709101957989.
# [I 2023-12-13 02:18:31,077] Trial 36 finished with value: 0.16538823078042592 and parameters: {'n_estimators': 9, 'learning_rate': 0.6031924028798046, 'max_depth': 1.360779578175747, 'min_samples_split': 16, 'min_samples_leaf': 10}. Best is trial 31 with value: 0.1659709101957989.
# [I 2023-12-13 02:18:32,063] Trial 37 finished with value: 0.1715253881935315 and parameters: {'n_estimators': 8, 'learning_rate': 0.6137172311731103, 'max_depth': 1.3504468742304363, 'min_samples_split': 17, 'min_samples_leaf': 8}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:33,050] Trial 38 finished with value: 0.1625054310244595 and parameters: {'n_estimators': 8, 'learning_rate': 0.6206159113364367, 'max_depth': 1.3914473000028225, 'min_samples_split': 16, 'min_samples_leaf': 7}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:34,207] Trial 39 finished with value: 0.10113252657510352 and parameters: {'n_estimators': 9, 'learning_rate': 0.5366940367341194, 'max_depth': 2.883978223502096, 'min_samples_split': 13, 'min_samples_leaf': 8}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:35,247] Trial 40 finished with value: 0.1009299190980229 and parameters: {'n_estimators': 8, 'learning_rate': 0.4583297811980669, 'max_depth': 2.2631953247407757, 'min_samples_split': 16, 'min_samples_leaf': 6}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:36,510] Trial 41 finished with value: 0.1658651498909538 and parameters: {'n_estimators': 10, 'learning_rate': 0.6097493847887637, 'max_depth': 1.247005043116757, 'min_samples_split': 19, 'min_samples_leaf': 10}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:37,773] Trial 42 finished with value: 0.1675719482697747 and parameters: {'n_estimators': 10, 'learning_rate': 0.6319336456031509, 'max_depth': 1.2473234977610912, 'min_samples_split': 19, 'min_samples_leaf': 10}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:39,003] Trial 43 finished with value: 0.1663874328555096 and parameters: {'n_estimators': 10, 'learning_rate': 0.6539391792109687, 'max_depth': 1.2047982988294803, 'min_samples_split': 19, 'min_samples_leaf': 8}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:40,226] Trial 44 finished with value: 0.16387446158692606 and parameters: {'n_estimators': 10, 'learning_rate': 0.6534244427524382, 'max_depth': 1.2375499352484227, 'min_samples_split': 19, 'min_samples_leaf': 8}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:41,805] Trial 45 finished with value: 0.1636119897863482 and parameters: {'n_estimators': 13, 'learning_rate': 0.5671720380988424, 'max_depth': 1.2054267274585821, 'min_samples_split': 17, 'min_samples_leaf': 7}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:43,142] Trial 46 finished with value: 0.16636521653990066 and parameters: {'n_estimators': 11, 'learning_rate': 0.4848340449024937, 'max_depth': 1.5190649981741593, 'min_samples_split': 19, 'min_samples_leaf': 9}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:47,263] Trial 47 finished with value: 0.06372291172619708 and parameters: {'n_estimators': 13, 'learning_rate': 0.40829995294231947, 'max_depth': 30.779897880647052, 'min_samples_split': 17, 'min_samples_leaf': 6}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:48,632] Trial 48 finished with value: 0.16356463045487044 and parameters: {'n_estimators': 11, 'learning_rate': 0.33469885342274197, 'max_depth': 1.5057103144591544, 'min_samples_split': 19, 'min_samples_leaf': 5}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:52,194] Trial 49 finished with value: 0.06463710646191471 and parameters: {'n_estimators': 12, 'learning_rate': 0.4828862019335569, 'max_depth': 21.58127818499237, 'min_samples_split': 18, 'min_samples_leaf': 9}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:53,620] Trial 50 finished with value: 0.06709260797994092 and parameters: {'n_estimators': 8, 'learning_rate': 0.24260821240155317, 'max_depth': 7.28963129720937, 'min_samples_split': 14, 'min_samples_leaf': 8}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:54,855] Trial 51 finished with value: 0.16868795229159303 and parameters: {'n_estimators': 10, 'learning_rate': 0.707580589543131, 'max_depth': 1.1913758655781412, 'min_samples_split': 19, 'min_samples_leaf': 9}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:56,209] Trial 52 finished with value: 0.15979357717003517 and parameters: {'n_estimators': 11, 'learning_rate': 0.7055002074802308, 'max_depth': 1.1619476406395923, 'min_samples_split': 19, 'min_samples_leaf': 9}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:57,444] Trial 53 finished with value: 0.16452884515866573 and parameters: {'n_estimators': 10, 'learning_rate': 0.6558427434877835, 'max_depth': 1.5673229302887008, 'min_samples_split': 17, 'min_samples_leaf': 7}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:18:58,350] Trial 54 finished with value: 0.10256913730720696 and parameters: {'n_estimators': 7, 'learning_rate': 0.5249437319997721, 'max_depth': 2.0957907858161153, 'min_samples_split': 20, 'min_samples_leaf': 8}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:00,913] Trial 55 finished with value: 0.0632757917455878 and parameters: {'n_estimators': 12, 'learning_rate': 0.5559132186441512, 'max_depth': 10.632845104941685, 'min_samples_split': 19, 'min_samples_leaf': 11}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:02,610] Trial 56 finished with value: 0.15502225755547624 and parameters: {'n_estimators': 14, 'learning_rate': 0.3914284787099952, 'max_depth': 1.1417675577304414, 'min_samples_split': 15, 'min_samples_leaf': 5}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:03,717] Trial 57 finished with value: 0.1541100582972085 and parameters: {'n_estimators': 9, 'learning_rate': 0.6403359019518396, 'max_depth': 1.3700085580377976, 'min_samples_split': 20, 'min_samples_leaf': 9}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:04,583] Trial 58 finished with value: 0.1631467774768598 and parameters: {'n_estimators': 7, 'learning_rate': 0.7198624392322369, 'max_depth': 1.641664978308775, 'min_samples_split': 17, 'min_samples_leaf': 11}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:06,396] Trial 59 finished with value: 0.1622333809321221 and parameters: {'n_estimators': 15, 'learning_rate': 0.4970707208282665, 'max_depth': 1.9748488551157848, 'min_samples_split': 18, 'min_samples_leaf': 7}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:07,500] Trial 60 finished with value: 0.159733047687388 and parameters: {'n_estimators': 9, 'learning_rate': 0.6862523363050049, 'max_depth': 1.1173907188122683, 'min_samples_split': 20, 'min_samples_leaf': 10}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:08,724] Trial 61 finished with value: 0.16279091733162626 and parameters: {'n_estimators': 10, 'learning_rate': 0.5946843782286293, 'max_depth': 1.2594342752120244, 'min_samples_split': 19, 'min_samples_leaf': 10}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:10,074] Trial 62 finished with value: 0.15758830852422737 and parameters: {'n_estimators': 11, 'learning_rate': 0.4462459760555296, 'max_depth': 1.4273175009916772, 'min_samples_split': 19, 'min_samples_leaf': 8}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:11,064] Trial 63 finished with value: 0.16740672273692236 and parameters: {'n_estimators': 8, 'learning_rate': 0.6376332576647489, 'max_depth': 1.7565139950277036, 'min_samples_split': 18, 'min_samples_leaf': 9}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:12,050] Trial 64 finished with value: 0.16669220877802546 and parameters: {'n_estimators': 8, 'learning_rate': 0.7447252672647305, 'max_depth': 1.7206062516495568, 'min_samples_split': 18, 'min_samples_leaf': 9}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:13,049] Trial 65 finished with value: 0.1685630354032288 and parameters: {'n_estimators': 8, 'learning_rate': 0.7524975671696434, 'max_depth': 1.010134064922974, 'min_samples_split': 17, 'min_samples_leaf': 9}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:13,919] Trial 66 finished with value: 0.16679291387333084 and parameters: {'n_estimators': 7, 'learning_rate': 0.7562770267400131, 'max_depth': 1.1104033963825057, 'min_samples_split': 16, 'min_samples_leaf': 7}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:14,550] Trial 67 finished with value: 0.1677684362826756 and parameters: {'n_estimators': 5, 'learning_rate': 0.7644115712986426, 'max_depth': 1.0338265273957494, 'min_samples_split': 15, 'min_samples_leaf': 9}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:15,201] Trial 68 finished with value: 0.163422153364947 and parameters: {'n_estimators': 5, 'learning_rate': 0.8045526287456801, 'max_depth': 1.0399498518733648, 'min_samples_split': 14, 'min_samples_leaf': 6}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:15,840] Trial 69 finished with value: 0.16808718054734084 and parameters: {'n_estimators': 5, 'learning_rate': 0.7610296855439904, 'max_depth': 1.09203721201624, 'min_samples_split': 16, 'min_samples_leaf': 7}. Best is trial 37 with value: 0.1715253881935315.
# [I 2023-12-13 02:19:16,236] Trial 70 finished with value: 0.17774928235979312 and parameters: {'n_estimators': 3, 'learning_rate': 0.8574258121039985, 'max_depth': 1.0450982060804925, 'min_samples_split': 15, 'min_samples_leaf': 5}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:16,634] Trial 71 finished with value: 0.16853190595501022 and parameters: {'n_estimators': 3, 'learning_rate': 0.8453886674885812, 'max_depth': 1.3356701388375918, 'min_samples_split': 13, 'min_samples_leaf': 5}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:17,028] Trial 72 finished with value: 0.15849372315916535 and parameters: {'n_estimators': 3, 'learning_rate': 0.8521090989651317, 'max_depth': 1.039043948965791, 'min_samples_split': 12, 'min_samples_leaf': 4}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:17,304] Trial 73 finished with value: 0.1660492659436653 and parameters: {'n_estimators': 2, 'learning_rate': 0.782863160991023, 'max_depth': 1.3385781192709247, 'min_samples_split': 13, 'min_samples_leaf': 5}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:17,935] Trial 74 finished with value: 0.16309303261754227 and parameters: {'n_estimators': 5, 'learning_rate': 0.8342561323648431, 'max_depth': 1.0111874730135693, 'min_samples_split': 15, 'min_samples_leaf': 4}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:18,332] Trial 75 finished with value: 0.1737080414282404 and parameters: {'n_estimators': 3, 'learning_rate': 0.7189240228585694, 'max_depth': 1.1200384164972397, 'min_samples_split': 14, 'min_samples_leaf': 2}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:18,727] Trial 76 finished with value: 0.1558543716520877 and parameters: {'n_estimators': 3, 'learning_rate': 0.943940213720988, 'max_depth': 1.117024326643164, 'min_samples_split': 14, 'min_samples_leaf': 3}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:19,118] Trial 77 finished with value: 0.1689633281796802 and parameters: {'n_estimators': 3, 'learning_rate': 0.8641594512679003, 'max_depth': 1.4441610860960996, 'min_samples_split': 13, 'min_samples_leaf': 2}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:19,515] Trial 78 finished with value: 0.16453642797297538 and parameters: {'n_estimators': 3, 'learning_rate': 0.8817863954379124, 'max_depth': 1.4615379430265436, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:19,909] Trial 79 finished with value: 0.1649272754894973 and parameters: {'n_estimators': 3, 'learning_rate': 0.8520924547363142, 'max_depth': 1.290171300565034, 'min_samples_split': 12, 'min_samples_leaf': 2}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:20,184] Trial 80 finished with value: 0.17434127293901103 and parameters: {'n_estimators': 2, 'learning_rate': 0.8118325789909873, 'max_depth': 1.1444940399119112, 'min_samples_split': 14, 'min_samples_leaf': 3}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:20,462] Trial 81 finished with value: 0.1738583673961334 and parameters: {'n_estimators': 2, 'learning_rate': 0.8118440606920491, 'max_depth': 1.1388668531262156, 'min_samples_split': 14, 'min_samples_leaf': 3}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:20,739] Trial 82 finished with value: 0.1769210261862515 and parameters: {'n_estimators': 2, 'learning_rate': 0.8022182632481987, 'max_depth': 1.343426792610485, 'min_samples_split': 13, 'min_samples_leaf': 3}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:21,015] Trial 83 finished with value: 0.1769337972419309 and parameters: {'n_estimators': 2, 'learning_rate': 0.8207450385602368, 'max_depth': 1.4690853406099718, 'min_samples_split': 12, 'min_samples_leaf': 3}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:21,290] Trial 84 finished with value: 0.17325999022482116 and parameters: {'n_estimators': 2, 'learning_rate': 0.7950647974048213, 'max_depth': 1.5908107338562785, 'min_samples_split': 12, 'min_samples_leaf': 3}. Best is trial 70 with value: 0.17774928235979312.
# [I 2023-12-13 02:19:21,565] Trial 85 finished with value: 0.1802127657876189 and parameters: {'n_estimators': 2, 'learning_rate': 0.8125199021908686, 'max_depth': 1.6223975169151288, 'min_samples_split': 13, 'min_samples_leaf': 3}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:21,858] Trial 86 finished with value: 0.102891606463112 and parameters: {'n_estimators': 2, 'learning_rate': 0.8180189899529633, 'max_depth': 2.6324922100886927, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:22,186] Trial 87 finished with value: 0.1791687319858273 and parameters: {'n_estimators': 2, 'learning_rate': 0.8023739420947309, 'max_depth': 1.63281071990667, 'min_samples_split': 12, 'min_samples_leaf': 3}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:22,463] Trial 88 finished with value: 0.16701826979334036 and parameters: {'n_estimators': 2, 'learning_rate': 0.9309868892389856, 'max_depth': 1.9139278531431498, 'min_samples_split': 12, 'min_samples_leaf': 3}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:22,739] Trial 89 finished with value: 0.17329351424597958 and parameters: {'n_estimators': 2, 'learning_rate': 0.8010750834050379, 'max_depth': 1.6073614474358575, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:23,334] Trial 90 finished with value: 0.07552177079201033 and parameters: {'n_estimators': 4, 'learning_rate': 0.8975944346761973, 'max_depth': 4.564130571974541, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:23,609] Trial 91 finished with value: 0.17714771242456095 and parameters: {'n_estimators': 2, 'learning_rate': 0.8059886832929453, 'max_depth': 1.6811018028748206, 'min_samples_split': 14, 'min_samples_leaf': 3}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:23,895] Trial 92 finished with value: 0.1085067469753218 and parameters: {'n_estimators': 2, 'learning_rate': 0.8145237674521074, 'max_depth': 2.22350383163779, 'min_samples_split': 14, 'min_samples_leaf': 3}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:24,170] Trial 93 finished with value: 0.1758376149627817 and parameters: {'n_estimators': 2, 'learning_rate': 0.7779414613706366, 'max_depth': 1.8728288025856585, 'min_samples_split': 14, 'min_samples_leaf': 4}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:24,707] Trial 94 finished with value: 0.10554306386671912 and parameters: {'n_estimators': 4, 'learning_rate': 0.9675015352374805, 'max_depth': 2.104984649209111, 'min_samples_split': 14, 'min_samples_leaf': 2}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:25,102] Trial 95 finished with value: 0.1728655508488894 and parameters: {'n_estimators': 3, 'learning_rate': 0.7798341720669952, 'max_depth': 1.8627393523887, 'min_samples_split': 13, 'min_samples_leaf': 4}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:25,380] Trial 96 finished with value: 0.1742534719312151 and parameters: {'n_estimators': 2, 'learning_rate': 0.7304720259400896, 'max_depth': 1.526783132212269, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:25,666] Trial 97 finished with value: 0.10859880500167753 and parameters: {'n_estimators': 2, 'learning_rate': 0.9977687661258707, 'max_depth': 2.481214128120568, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:25,943] Trial 98 finished with value: 0.17771136828824485 and parameters: {'n_estimators': 2, 'learning_rate': 0.8691101697496393, 'max_depth': 1.6847922677924174, 'min_samples_split': 11, 'min_samples_leaf': 4}. Best is trial 85 with value: 0.1802127657876189.
# [I 2023-12-13 02:19:26,507] Trial 99 finished with value: 0.08417229856918945 and parameters: {'n_estimators': 4, 'learning_rate': 0.8688807122783742, 'max_depth': 3.1428560784700648, 'min_samples_split': 11, 'min_samples_leaf': 4}. Best is trial 85 with value: 0.1802127657876189.
# Accuracy: 0.1802127657876189
# Best hyperparameters: {'n_estimators': 2, 'learning_rate': 0.8125199021908686, 'max_depth': 1.6223975169151288, 'min_samples_split': 13, 'min_samples_leaf': 3}

# %%
# best params
n_estimators = 2
learning_rate = 0.8
base_model_params = {'max_depth': 2, 'min_samples_split': 13, 'min_samples_leaf': 3}

# %% [markdown]
# ## Задание 4. Интерпретация бустингового (2 балл)
#
# Постройте калибровочную кривую для вашей лучшей модели бустинга. Насколько хорошо бустинг оценивает вероятности? Постройте также калибровочную кривую для логистической регрессии, сравните их между собой. Проанализируйте полученные результаты.

# %%
def plot_calibration_curve(y_test, preds, ax, title):
    bin_middle_points = []
    bin_real_ratios = []
    n_bins = 10

    for i in range(n_bins):
        l = i * 1.0 / n_bins
        r = (i+1) * 1.0 / n_bins
        bin_middle_points.append((r + l) / 2)
        bin_real_ratios.append(np.sum(y_test * np.where((preds >= l) & (preds < r), 1, 0))/np.sum(np.where((preds >= l) & (preds < r), 1, 0)))


    ax.grid()
    ax.set_title(f'{title} Calibration curve', fontsize=15)
    ax.set_xlabel('probs for positive class')
    ax.set_ylabel('true ratios')
    ax.plot(bin_middle_points, bin_real_ratios)
    ax.plot([0,1], [0,1], '--')
    plt.ylim([-0.05, 1.05])

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 7))

model = Boosting(base_model_params=base_model_params, n_estimators=n_estimators, learning_rate=learning_rate)
model.fit(x_train, y_train, x_valid, y_valid)
y_pred = model.predict_proba(x_test)[:, 0]
plot_calibration_curve(y_test, y_pred, ax[0], 'Boosting')

model = LogisticRegression()
model.fit(x_train, y_train)
y_pred_proba = model.predict_proba(x_test)[:, 1]
plot_calibration_curve(y_test, y_pred_proba, ax[1], 'Logistic regr.')
plt.show()

# %% [markdown]
# Теперь попробуем оценить важность признаков для бустинга.
#
# Поскольку наша базовая модель - это дерево из `sklearn`, мы можем вычислить важность признака отдельно для каждого дерева и усреднить (воспользуйтесь `feature_importances_` у `DecisionTreeRegressor`), после этого нормировать значения, чтобы они суммировались в единицу (обратите внимание, что они должны быть неотрицательными - иначе вы что-то сделали не так).
#
# Допишите в вашей реализации бустинга функцию `feature_importances_` чтобы она возвращала описанные выше важности признаков.
#
# Нарисуйте столбчатую диаграмму важности признаков. На соседнем графике нарисуйте важность признаков для логистической регрессии, для этого используйте модули весов. Сравните графики. Проанализируйте полученные результаты.

# %%
boosting = Boosting(base_model_params=base_model_params, n_estimators=n_estimators, learning_rate=learning_rate)
boosting.fit(x_train, y_train, x_valid, y_valid)
f_imps_boosting = boosting.feature_importances_

logreg = LogisticRegression()
logreg.fit(x_train, y_train)
f_imps_logreg = np.abs(logreg.coef_[0])


f, ax = plt.subplots(1, 2, figsize=(20, 7))
ax[0].hist(f_imps_boosting)
ax[0].set_title('Boosting feature importances', fontsize=15)
ax[1].hist(f_imps_logreg, color='orange')
ax[1].set_title('Logistic regr. feature importances', fontsize=15)
plt.show()

# %% [markdown]
# Кстати, чаще всего излишние признаки могут вредить качеству бустинга. Попробуйте отфильтровать на основании диаграммы хвост наименее важных признаков и снова обучить модель (с теми же гиперпараметрами). Стало ли лучше?

# %%
# YOUR CODE:

# %% [markdown]
# ## Задание 5 (бонус). Блендинговое (1 балл)
#
# Реализуйте блендинг над вашей лучшей моделью и логистической регрессией. Улучшилось ли качество?

# %%
# YOUR CODE:

# %% [markdown]
# ## Задание 6 (бонус). Катбустовое (1 балл)
#
# Запустите [CatBoost](https://catboost.ai/en/docs/concepts/python-quickstart) на наших данных, сравните с вашей реализацией. Где получилось лучше?

# %%
# YOUR CODE:

# %% [markdown]
# ## Социализационный бонус. Новогоднее 🎆 (0.5 балла)
#
# Сфотографируйтесь с наряженной новогодней или рождественской ёлкой! Приложите фотографию, опишите свои впечатления, чего вы ждете от нового 2024 года?
